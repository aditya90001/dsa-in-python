# %%
#here we learn how to store frequency for a dictionary

# %%
nums=[1,2,1,2,4,5,6,5,6,4,6,6,6]
dict={}
n=len(nums)
for i in range (n):
  dict[nums[i]]=dict.get(nums[i],0)+1

# %%
dict[6]
# Out:
# 5
